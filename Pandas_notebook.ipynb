# %%
import pandas as pd

# %%
pwd
# Out:
# 'E:\\machine learning\\Tensorflow_machine'

# %%
df = pd.read_csv("maroore.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2018                     Level 3                 ZZ11
# 32441  2018                     Level 3                 ZZ11
# 32442  2018                     Level 3                 ZZ11
# 32443  2018                     Level 3                 ZZ11
# 32444  2018                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df['Year']
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 32440    2018
# 32441    2018
# 32442    2018
# 32443    2018
# 32444    2018
# Name: Year, Length: 32445, dtype: int64

# %%
df[['Year','Industry_code_NZSIOC']]
# Out:
#        Year Industry_code_NZSIOC
# 0      2018                99999
# 1      2018                99999
# 2      2018                99999
# 3      2018                99999
# 4      2018                99999
# ...     ...                  ...
# 32440  2018                 ZZ11
# 32441  2018                 ZZ11
# 32442  2018                 ZZ11
# 32443  2018                 ZZ11
# 32444  2018                 ZZ11
#
# [32445 rows x 2 columns]

# %%
df['Year'].max()
# Out:
# 2018

# %%
df['Year'].min()
# Out:
# 2018

# %%
df.describe()
# Out:
#           Year
# count  32445.0
# mean    2018.0
# std        0.0
# min     2018.0
# 25%     2018.0
# 50%     2018.0
# 75%     2018.0
# max     2018.0

# %%
df['Year'] > 2013
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 32440    True
# 32441    True
# 32442    True
# 32443    True
# 32444    True
# Name: Year, Length: 32445, dtype: bool

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2018                     Level 3                 ZZ11
# 32441  2018                     Level 3                 ZZ11
# 32442  2018                     Level 3                 ZZ11
# 32443  2018                     Level 3                 ZZ11
# 32444  2018                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
myfilter = df['Year'] >= 2018

# %%
df[myfilter]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2018                     Level 3                 ZZ11
# 32441  2018                     Level 3                 ZZ11
# 32442  2018                     Level 3                 ZZ11
# 32443  2018                     Level 3                 ZZ11
# 32444  2018                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-6daa3d5b98a9> in <module>
# ----> 1 df.as_matrix()
#
# ~\anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'as_matrix'
